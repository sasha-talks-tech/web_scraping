# %% [markdown]
# # Web Scraping BoxOfficeMojo with BeautifulSoup (more data added)

# %% [markdown]
# **The goal** of this notebook is to produce a dataframe with the information about movies from [Box Office Mojo](https://www.boxofficemojo.com). The dataset obtained from webscraping will be used for exploratory data analysis, linear regression modeling and feature engineering. The resulting dataframe will be saved in the csv format for easier access in the future, as well as in movies.py python file, located in the same repository, for future projects. This notebook is a continuation on the "attempt3", where I was scraping data for 2019. It turns out I need more data points, as the budget values were missing from MANY movies.

# %% [markdown]
# **The code** executed below will **result** in extracting data about domestic movies from 2019 (roughly 800 or so), and will provide us with some insights, such as movie title, total domestic gross revenue, runtime, rating, and budget.

# %% [markdown]
# #### Tools and Libraries

# %%
from bs4 import BeautifulSoup
import requests
import time, os
import dateutil.parser
import numpy as np
import pandas as pd
import re
import seaborn as sns 
import matplotlib.pyplot as plt

from urllib.parse import urljoin

# %% [markdown]
# #### URL details for the request

# %%
extension_url = '/year/2018/?ref_=bo_yl_table_1'
base_url = 'https://www.boxofficemojo.com' 
url = base_url + extension_url

# %%
response = requests.get(url)
page = response.text
soup = BeautifulSoup(page, 'lxml')
table = soup.find_all('table')
df = pd.read_html(str(table))[0]
df.drop(columns=['Genre', 'Budget', 'Running Time'], inplace=True)

# %% [markdown]
# #### Helper functions: $ --> integer, hours + min --> min, date --> datestring

# %%
def money_to_int(moneystring):
    if type(moneystring) != float:
        moneystring = moneystring.replace('$', '').replace(',', '')
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    if runtimestring != None:
        runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

# %% [markdown]
# #### Helper function: findNext( ) to find sibling object values.

# %%
def get_movie_value(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    
    if not obj: 
        return None
    
    # this works for most of the values
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text 
    else:
        return None

# %% [markdown]
# #### Helper function: extracts movie stats, such as title, money, rating etc. and puts them into a dictionary.

# %% [markdown]
# Removal of *release_date* clause in the function below was necessary. It was creating the bug that I couldn't identify quickly enough, and I had to proceed. I will sacrifice the date a movie was released for the sake of this particular exercise.

# %%
def get_movie_dict(link):
    '''
    From BoxOfficeMojo link stub, request movie html, parse with BeautifulSoup, and
    collect 
        - title 
        - domestic gross
        - runtime 
        - MPAA rating
        - full release date
    Return information as a dictionary.
    '''
    
    base_url = 'https://www.boxofficemojo.com'
    
    #Create full url to scrape
    url = urljoin(base_url, link)
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")


    headers = ['movie_title', 'domestic_total_gross',
               'runtime_minutes', 'rating', 'budget']

    #Get title
    title_string = soup.find('title').text
    title = title_string.split('-')[0].strip()

    #Get domestic gross
    try:
        raw_domestic_total_gross = (soup.find(class_='mojo-performance-summary-table')
                                    .find_all('span', class_='money')[0]
                                    .text
                               )
    except:
        raw_domestic_total_gross = float("NaN")

    if type(raw_domestic_total_gross) == float or type(raw_domestic_total_gross) == 'NoneType':
        print('This is NaN')
        domestic_total_gross = float("NaN")
    else:
        domestic_total_gross = money_to_int(raw_domestic_total_gross)

    #Get runtime
    raw_runtime = get_movie_value(soup,'Running')
    if type(raw_runtime) != float and type(raw_runtime) != 'NoneType':
        runtime = runtime_to_minutes(raw_runtime)

    #Get rating
    rating = get_movie_value(soup,'MPAA')

#     I had to take out thios part, because it was creating the bug in the code, 
#.    so I couldn't pull enough values until I took this block out.

#     #Get release date
#     if '-' in get_movie_value(soup, 'Release Date'):
#         raw_release_date = get_movie_value(soup,'Release Date').split('-')[0]
#     elif '(' in get_movie_value(soup, 'Release Date'):
#         raw_release_date = get_movie_value(soup,'Release Date').split('(')[0]
#     else:
#         raw_release_date = get_movie_value(soup,'Release Date').split('(')[0]
#     release_date = to_date(raw_release_date)



    # Get budget alt
    raw_budget = get_movie_value(soup,'Budget')
    if raw_budget:
        budget = money_to_int(raw_budget)
    else:
        budget = 0

    #Create movie dictionary and return
    movie_dict = dict(zip(headers,[title,
                                domestic_total_gross,
                                runtime,
                                rating,
                                
                                budget]))

    return movie_dict

# %% [markdown]
# ###### Now, we create expressions to sort through the html soup.

# %%
table = soup.find('table')
rows = [row for row in table.find_all('tr')]

# %% [markdown]
# It seems like we are looking for the values attached to the "href" attribute, as is seems to be holding the extension to our base url. We use those extension links to access each individual movie in order to extract data.

# %%
rows[1].find_all('td')[1].find('a')
# Out:
# <a class="a-link-normal" href="/release/rl2992866817/?ref_=bo_yld_table_1">Black Panther</a>

# %%
rows[1].find_all('td')[1].find('a')['href']
# Out:
# '/release/rl2992866817/?ref_=bo_yld_table_1'

# %% [markdown]
# We slice the url extension that we found via the path shown above, and we manually set up the beginning and the end of the string that we are interested in. For instance, to extract the value of *rl3059975681* from the text *'/release/rl3059975681/?ref_=bo_yld_table_1'* that was returned in the cell above, we create variable called *section*. This variable will hold the extension of the movie link. Then we crop it by defining the *beginning* and the *end* of the string, and use it to slice the *section* thus defining the *substring*. We save those movie stubs into the *mojo_links* list. I've been told it works faster with Selenium, but I chose to focus on [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) instead.

# %%
mojo_links = []
for i in range(1,800):
    section = rows[i].find('a')['href']
    start = section.find("release/") + len("release/")
    end = section.find("/?ref_")
    substring = section[start:end]
    mojo_links.append(substring)
mojo_links
# Out:
# ['rl2992866817',
#  'rl3043198465',
#  'rl2071758337',
#  'rl1602061825',
#  'rl2488436225',
#  'rl3075966465',
#  'rl3095234049',
#  'rl2449573377',
#  'rl2088535553',
#  'rl1954383361',
#  'rl2734720513',
#  'rl2164360705',
#  'rl3108800001',
#  'rl3439363585',
#  'rl2399176193',
#  'rl2742978049',
#  'rl1157858817',
#  'rl3111945729',
#  'rl1342342657',
#  'rl1534625281',
#  'rl2105509377',
#  'rl2206107137',
#  'rl2977793537',
#  'rl1700234753',
#  'rl1828947457',
#  'rl1493206529',
#  'rl3380381185',
#  'rl1594197505',
#  'rl879986177',
#  'rl3263137281',
#  'rl2708702721',
#  'rl494765569',
#  'rl2122286593',
#  'rl1795655169',
#  'rl772048385',
#  'rl1761904129',
#  'rl2886043137',
#  'rl2735179265',
#  'rl3724838401',
#  'rl3322250753',
#  'rl1146979841',
#  'rl3657729537',
#  'rl2533721601',
#  'rl2248443393',
#  'rl2433058305',
#  'rl1728480769',
#  'rl2449901057',
#  'rl2902820353',
#  'rl537363969',
#  'rl2651227649',
#  'rl2315617793',
#  'rl621053441',
#  'rl3959719425',
#  'rl1476888065',
#  'rl1409648129',
#  'rl2550302209',
#  'rl91719169',
#  'rl1493468673',
#  'rl1728415233',
#  'rl1409582593',
#  'rl3037169153',
#  'rl2466547201',
#  'rl3154544129',
#  'rl1392936449',
#  'rl1795458561',
#  'rl3892807169',
#  'rl822576641',
#  'rl17204737',
#  'rl453281281',
#  'rl2265220609',
#  'rl554075649',
#  'rl2584118785',
#  'rl2701559297',
#  'rl419857921',
#  'rl1493665281',
#  'rl2969732609',
#  'rl201623041',
#  'rl3976627713',
#  'rl184911361',
#  'rl2852619777',
#  'rl1594263041',
#  'rl822511105',
#  'rl4194534913',
#  'rl1812366849',
#  'rl2567079425',
#  'rl1543865857',
#  'rl2063894017',
#  'rl336037377']

# %% [markdown]
# ###### Now, we append those movie link stubs into a dictionary, using our helper function get_movie_dict() from above.

# %% [markdown]
# **Warning:** The cell below takes long time to run. I saved its output in the *return_titles()* function, located in *movies.py* module. It's also available as a text file called *scraping output*. All are located in the same repository. **Run at your own risk.**

# %%
dicts = []

for link in mojo_links:
    dicts.append(get_movie_dict('/release/{}/'.format(link)))

dicts
# Out:
# [{'movie_title': 'Black Panther',
#   'domestic_total_gross': 700059566,
#   'runtime_minutes': 134,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Avengers: Infinity War',
#   'domestic_total_gross': 678815482,
#   'runtime_minutes': 149,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Incredibles 2',
#   'domestic_total_gross': 608581744,
#   'runtime_minutes': 118,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Jurassic World: Fallen Kingdom',
#   'domestic_total_gross': 417719760,
#   'runtime_minutes': 128,
#   'rating': 'PG-13',
#   'budget': 170000000},
#  {'movie_title': 'Deadpool 2',
#   'domestic_total_gross': 318491426,
#   'runtime_minutes': 119,
#   'rating': 'R',
#   'budget': 110000000},
#  {'movie_title': 'The Grinch',
#   'domestic_total_gross': 270620950,
#   'runtime_minutes': 85,
#   'rating': 'PG',
#   'budget': 75000000},
#  {'movie_title': 'Jumanji: Welcome to the Jungle',
#   'domestic_total_gross': 404515480,
#   'runtime_minutes': 119,
#   'rating': 'PG-13',
#   'budget': 90000000},
#  {'movie_title': 'Mission: Impossible',
#   'domestic_total_gross': 220159104,
#   'runtime_minutes': 147,
#   'rating': 'PG-13',
#   'budget': 178000000},
#  {'movie_title': 'Ant',
#   'domestic_total_gross': 216648740,
#   'runtime_minutes': 118,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Solo: A Star Wars Story',
#   'domestic_total_gross': 213767512,
#   'runtime_minutes': 135,
#   'rating': 'PG-13',
#   'budget': 275000000},
#  {'movie_title': 'Venom',
#   'domestic_total_gross': 213515506,
#   'runtime_minutes': 112,
#   'rating': 'PG-13',
#   'budget': 100000000},
#  {'movie_title': 'A Star Is Born',
#   'domestic_total_gross': 215288866,
#   'runtime_minutes': 136,
#   'rating': 'R',
#   'budget': 36000000},
#  {'movie_title': 'Aquaman',
#   'domestic_total_gross': 335061807,
#   'runtime_minutes': 143,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Bohemian Rhapsody',
#   'domestic_total_gross': 216428042,
#   'runtime_minutes': 134,
#   'rating': 'PG-13',
#   'budget': 52000000},
#  {'movie_title': 'A Quiet Place',
#   'domestic_total_gross': 188024361,
#   'runtime_minutes': 90,
#   'rating': 'PG-13',
#   'budget': 17000000},
#  {'movie_title': 'Ralph Breaks the Internet',
#   'domestic_total_gross': 201091711,
#   'runtime_minutes': 112,
#   'rating': 'PG',
#   'budget': 175000000},
#  {'movie_title': 'Crazy Rich Asians',
#   'domestic_total_gross': 174532921,
#   'runtime_minutes': None,
#   'rating': 'PG-13',
#   'budget': 30000000},
#  {'movie_title': 'Hotel Transylvania 3: Summer Vacation',
#   'domestic_total_gross': 167510016,
#   'runtime_minutes': 97,
#   'rating': 'PG',
#   'budget': 80000000},
#  {'movie_title': 'Halloween',
#   'domestic_total_gross': 159342015,
#   'runtime_minutes': 106,
#   'rating': 'R',
#   'budget': 10000000},
#  {'movie_title': 'Fantastic Beasts: The Crimes of Grindelwald',
#   'domestic_total_gross': 159555901,
#   'runtime_minutes': 134,
#   'rating': 'PG-13',
#   'budget': 200000000},
#  {'movie_title': 'The Meg',
#   'domestic_total_gross': 145443742,
#   'runtime_minutes': 113,
#   'rating': 'PG-13',
#   'budget': 130000000},
#  {'movie_title': "Ocean's 8",
#   'domestic_total_gross': 140218711,
#   'runtime_minutes': 110,
#   'rating': 'PG-13',
#   'budget': 70000000},
#  {'movie_title': 'Ready Player One',
#   'domestic_total_gross': 137690172,
#   'runtime_minutes': 140,
#   'rating': 'PG-13',
#   'budget': 175000000},
#  {'movie_title': 'The Greatest Showman',
#   'domestic_total_gross': 174340174,
#   'runtime_minutes': 105,
#   'rating': 'PG',
#   'budget': 84000000},
#  {'movie_title': 'Mamma Mia! Here We Go Again',
#   'domestic_total_gross': 120634935,
#   'runtime_minutes': 114,
#   'rating': 'PG-13',
#   'budget': 75000000},
#  {'movie_title': 'The Nun',
#   'domestic_total_gross': 117450119,
#   'runtime_minutes': 96,
#   'rating': 'R',
#   'budget': 22000000},
#  {'movie_title': 'Peter Rabbit',
#   'domestic_total_gross': 115253424,
#   'runtime_minutes': 95,
#   'rating': 'PG',
#   'budget': 50000000},
#  {'movie_title': 'Creed II',
#   'domestic_total_gross': 115715889,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'budget': 50000000},
#  {'movie_title': 'Spider',
#   'domestic_total_gross': 190241310,
#   'runtime_minutes': 117,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Mary Poppins Returns',
#   'domestic_total_gross': 171958438,
#   'runtime_minutes': 130,
#   'rating': 'PG',
#   'budget': 130000000},
#  {'movie_title': 'Star Wars: Episode VIII',
#   'domestic_total_gross': 620181382,
#   'runtime_minutes': 152,
#   'rating': 'PG-13',
#   'budget': 317000000},
#  {'movie_title': 'The Equalizer 2',
#   'domestic_total_gross': 102084362,
#   'runtime_minutes': 121,
#   'rating': 'R',
#   'budget': 62000000},
#  {'movie_title': 'Rampage',
#   'domestic_total_gross': 101028233,
#   'runtime_minutes': 107,
#   'rating': 'PG-13',
#   'budget': 120000000},
#  {'movie_title': 'A Wrinkle in Time',
#   'domestic_total_gross': 100478608,
#   'runtime_minutes': 109,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Fifty Shades Freed',
#   'domestic_total_gross': 100407760,
#   'runtime_minutes': 105,
#   'rating': 'R',
#   'budget': 55000000},
#  {'movie_title': 'Christopher Robin',
#   'domestic_total_gross': 99215042,
#   'runtime_minutes': 104,
#   'rating': 'PG',
#   'budget': 75000000},
#  {'movie_title': 'I Can Only Imagine',
#   'domestic_total_gross': 83482352,
#   'runtime_minutes': 110,
#   'rating': 'PG',
#   'budget': 7000000},
#  {'movie_title': 'Smallfoot',
#   'domestic_total_gross': 83240103,
#   'runtime_minutes': 96,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'The Post',
#   'domestic_total_gross': 81903458,
#   'runtime_minutes': 116,
#   'rating': 'PG-13',
#   'budget': 50000000},
#  {'movie_title': 'Night School',
#   'domestic_total_gross': 77339130,
#   'runtime_minutes': 111,
#   'rating': 'PG-13',
#   'budget': 29000000},
#  {'movie_title': 'Bumblebee',
#   'domestic_total_gross': 127195589,
#   'runtime_minutes': 114,
#   'rating': 'PG-13',
#   'budget': 135000000},
#  {'movie_title': 'The First Purge',
#   'domestic_total_gross': 69488745,
#   'runtime_minutes': 97,
#   'rating': 'R',
#   'budget': 13000000},
#  {'movie_title': 'Game Night',
#   'domestic_total_gross': 69179066,
#   'runtime_minutes': 100,
#   'rating': 'R',
#   'budget': 37000000},
#  {'movie_title': 'Book Club',
#   'domestic_total_gross': 68566296,
#   'runtime_minutes': 104,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The House with a Clock in Its Walls',
#   'domestic_total_gross': 68549695,
#   'runtime_minutes': 105,
#   'rating': 'PG',
#   'budget': 42000000},
#  {'movie_title': 'Skyscraper',
#   'domestic_total_gross': 68420120,
#   'runtime_minutes': 102,
#   'rating': 'PG-13',
#   'budget': 125000000},
#  {'movie_title': 'Insidious: The Last Key',
#   'domestic_total_gross': 67745330,
#   'runtime_minutes': 103,
#   'rating': 'PG-13',
#   'budget': 10000000},
#  {'movie_title': 'Instant Family',
#   'domestic_total_gross': 67363237,
#   'runtime_minutes': 118,
#   'rating': 'PG-13',
#   'budget': 48000000},
#  {'movie_title': 'The Mule',
#   'domestic_total_gross': 103804407,
#   'runtime_minutes': 116,
#   'rating': 'R',
#   'budget': 50000000},
#  {'movie_title': 'Blockers',
#   'domestic_total_gross': 60311495,
#   'runtime_minutes': 102,
#   'rating': 'R',
#   'budget': 21000000},
#  {'movie_title': 'Pacific Rim: Uprising',
#   'domestic_total_gross': 59874525,
#   'runtime_minutes': 111,
#   'rating': 'PG-13',
#   'budget': 150000000},
#  {'movie_title': 'Tomb Raider',
#   'domestic_total_gross': 58250803,
#   'runtime_minutes': 119,
#   'rating': 'PG-13',
#   'budget': 94000000},
#  {'movie_title': 'Maze Runner: The Death Cure',
#   'domestic_total_gross': 58032443,
#   'runtime_minutes': 143,
#   'rating': 'PG-13',
#   'budget': 62000000},
#  {'movie_title': 'Tag',
#   'domestic_total_gross': 54730625,
#   'runtime_minutes': 100,
#   'rating': 'R',
#   'budget': 28000000},
#  {'movie_title': 'The Nutcracker and the Four Realms',
#   'domestic_total_gross': 54858851,
#   'runtime_minutes': 99,
#   'rating': 'PG',
#   'budget': 120000000},
#  {'movie_title': 'A Simple Favor',
#   'domestic_total_gross': 53548586,
#   'runtime_minutes': 117,
#   'rating': 'R',
#   'budget': 20000000},
#  {'movie_title': 'Life of the Party',
#   'domestic_total_gross': 53059911,
#   'runtime_minutes': 105,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The Predator',
#   'domestic_total_gross': 51024708,
#   'runtime_minutes': 107,
#   'rating': 'R',
#   'budget': 88000000},
#  {'movie_title': 'Overboard',
#   'domestic_total_gross': 50316123,
#   'runtime_minutes': 112,
#   'rating': 'PG-13',
#   'budget': 12000000},
#  {'movie_title': 'Sicario: Day of the Soldado',
#   'domestic_total_gross': 50072235,
#   'runtime_minutes': 122,
#   'rating': 'R',
#   'budget': 35000000},
#  {'movie_title': 'I Feel Pretty',
#   'domestic_total_gross': 48795601,
#   'runtime_minutes': 110,
#   'rating': 'PG-13',
#   'budget': 32000000},
#  {'movie_title': 'BlacKkKlansman',
#   'domestic_total_gross': 49275340,
#   'runtime_minutes': 135,
#   'rating': 'R',
#   'budget': 15000000},
#  {'movie_title': 'The Shape of Water',
#   'domestic_total_gross': 63859435,
#   'runtime_minutes': 123,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Red Sparrow',
#   'domestic_total_gross': 46874505,
#   'runtime_minutes': 140,
#   'rating': 'R',
#   'budget': 69000000},
#  {'movie_title': 'Breaking In',
#   'domestic_total_gross': 46840590,
#   'runtime_minutes': 88,
#   'rating': 'PG-13',
#   'budget': 6000000},
#  {'movie_title': 'Goosebumps 2: Haunted Halloween',
#   'domestic_total_gross': 46700633,
#   'runtime_minutes': 90,
#   'rating': 'PG',
#   'budget': 35000000},
#  {'movie_title': '12 Strong',
#   'domestic_total_gross': 45819713,
#   'runtime_minutes': 130,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Den of Thieves',
#   'domestic_total_gross': 44947622,
#   'runtime_minutes': 140,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'First Man',
#   'domestic_total_gross': 44936545,
#   'runtime_minutes': 141,
#   'rating': 'PG-13',
#   'budget': 59000000},
#  {'movie_title': 'Hereditary',
#   'domestic_total_gross': 44069456,
#   'runtime_minutes': 127,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': "Tyler Perry's Acrimony",
#   'domestic_total_gross': 43549096,
#   'runtime_minutes': None,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Sherlock Gnomes',
#   'domestic_total_gross': 43242871,
#   'runtime_minutes': 86,
#   'rating': 'PG',
#   'budget': 59000000},
#  {'movie_title': 'Uncle Drew',
#   'domestic_total_gross': 42469946,
#   'runtime_minutes': 103,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Widows',
#   'domestic_total_gross': 42402632,
#   'runtime_minutes': 129,
#   'rating': 'R',
#   'budget': 42000000},
#  {'movie_title': 'Pitch Perfect 3',
#   'domestic_total_gross': 104897530,
#   'runtime_minutes': 93,
#   'rating': 'PG-13',
#   'budget': 45000000},
#  {'movie_title': 'Truth or Dare',
#   'domestic_total_gross': 41411015,
#   'runtime_minutes': 100,
#   'rating': 'PG-13',
#   'budget': 3500000},
#  {'movie_title': 'Paddington 2',
#   'domestic_total_gross': 40891591,
#   'runtime_minutes': 103,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Love, Simon',
#   'domestic_total_gross': 40826341,
#   'runtime_minutes': 110,
#   'rating': 'PG-13',
#   'budget': 17000000},
#  {'movie_title': 'Darkest Hour',
#   'domestic_total_gross': 56468410,
#   'runtime_minutes': 125,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The Commuter',
#   'domestic_total_gross': 36343858,
#   'runtime_minutes': 104,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The 15:17 to Paris',
#   'domestic_total_gross': 36276286,
#   'runtime_minutes': 94,
#   'rating': 'PG-13',
#   'budget': 30000000},
#  {'movie_title': 'Mile 22',
#   'domestic_total_gross': 36108758,
#   'runtime_minutes': 94,
#   'rating': 'R',
#   'budget': 50000000},
#  {'movie_title': 'Alpha',
#   'domestic_total_gross': 35857181,
#   'runtime_minutes': 96,
#   'rating': 'PG-13',
#   'budget': 51000000},
#  {'movie_title': 'Peppermint',
#   'domestic_total_gross': 35418723,
#   'runtime_minutes': 101,
#   'rating': 'R',
#   'budget': 25000000},
#  {'movie_title': 'Death Wish',
#   'domestic_total_gross': 34017028,
#   'runtime_minutes': 107,
#   'rating': 'R',
#   'budget': 30000000},
#  {'movie_title': 'The Spy Who Dumped Me',
#   'domestic_total_gross': 33562069,
#   'runtime_minutes': 117,
#   'rating': 'R',
#   'budget': 40000000},
#  {'movie_title': 'Annihilation',
#   'domestic_total_gross': 32732301,
#   'runtime_minutes': 115,
#   'rating': 'R',
#   'budget': 40000000},
#  {'movie_title': 'Green Book',
#   'domestic_total_gross': 85080171,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'budget': 23000000},
#  {'movie_title': 'Isle of Dogs',
#   'domestic_total_gross': 32015231,
#   'runtime_minutes': 101,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': "Nobody's Fool",
#   'domestic_total_gross': 31713110,
#   'runtime_minutes': 110,
#   'rating': 'R',
#   'budget': 19000000},
#  {'movie_title': 'Adrift',
#   'domestic_total_gross': 31445012,
#   'runtime_minutes': 96,
#   'rating': 'PG-13',
#   'budget': 35000000},
#  {'movie_title': 'Ferdinand',
#   'domestic_total_gross': 84410380,
#   'runtime_minutes': 108,
#   'rating': 'PG',
#   'budget': 111000000},
#  {'movie_title': 'Robin Hood',
#   'domestic_total_gross': 30824628,
#   'runtime_minutes': 116,
#   'rating': 'PG-13',
#   'budget': 100000000},
#  {'movie_title': 'Super Troopers 2',
#   'domestic_total_gross': 30617396,
#   'runtime_minutes': 100,
#   'rating': 'R',
#   'budget': 13500000},
#  {'movie_title': 'Slender Man',
#   'domestic_total_gross': 30569484,
#   'runtime_minutes': 93,
#   'rating': 'PG-13',
#   'budget': 10000000},
#  {'movie_title': 'Three Billboards Outside Ebbing, Missouri',
#   'domestic_total_gross': 54513740,
#   'runtime_minutes': 115,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Coco',
#   'domestic_total_gross': 209726015,
#   'runtime_minutes': 105,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Teen Titans GO! to the Movies',
#   'domestic_total_gross': 29790236,
#   'runtime_minutes': 84,
#   'rating': 'PG',
#   'budget': 10000000},
#  {'movie_title': 'Hostiles',
#   'domestic_total_gross': 29819114,
#   'runtime_minutes': 134,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Hate U Give',
#   'domestic_total_gross': 29719483,
#   'runtime_minutes': 133,
#   'rating': 'PG-13',
#   'budget': 23000000},
#  {'movie_title': 'I, Tonya',
#   'domestic_total_gross': 30014539,
#   'runtime_minutes': 119,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Searching',
#   'domestic_total_gross': 26020957,
#   'runtime_minutes': 102,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Winchester',
#   'domestic_total_gross': 25091816,
#   'runtime_minutes': 99,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The Strangers: Prey at Night',
#   'domestic_total_gross': 24586708,
#   'runtime_minutes': 85,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'White Boy Rick',
#   'domestic_total_gross': 24011188,
#   'runtime_minutes': 111,
#   'rating': 'R',
#   'budget': 29000000},
#  {'movie_title': 'Second Act',
#   'domestic_total_gross': 39282227,
#   'runtime_minutes': 103,
#   'rating': 'PG-13',
#   'budget': 16000000},
#  {'movie_title': "Molly's Game",
#   'domestic_total_gross': 28780744,
#   'runtime_minutes': 140,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': "Won't You Be My Neighbor?",
#   'domestic_total_gross': 22835787,
#   'runtime_minutes': 95,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Overlord',
#   'domestic_total_gross': 21704844,
#   'runtime_minutes': 110,
#   'rating': 'R',
#   'budget': 38000000},
#  {'movie_title': 'Holmes & Watson',
#   'domestic_total_gross': 30573626,
#   'runtime_minutes': 90,
#   'rating': 'PG-13',
#   'budget': 42000000},
#  {'movie_title': 'Proud Mary',
#   'domestic_total_gross': 20877013,
#   'runtime_minutes': 89,
#   'rating': 'R',
#   'budget': 14000000},
#  {'movie_title': 'The Happytime Murders',
#   'domestic_total_gross': 20706452,
#   'runtime_minutes': 91,
#   'rating': 'R',
#   'budget': 40000000},
#  {'movie_title': 'Phantom Thread',
#   'domestic_total_gross': 21198205,
#   'runtime_minutes': 130,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'SuperFly',
#   'domestic_total_gross': 20545116,
#   'runtime_minutes': 116,
#   'rating': 'R',
#   'budget': 16000000},
#  {'movie_title': 'Vice',
#   'domestic_total_gross': 47836282,
#   'runtime_minutes': 132,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Show Dogs',
#   'domestic_total_gross': 17857020,
#   'runtime_minutes': 92,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Bad Times at the El Royale',
#   'domestic_total_gross': 17839115,
#   'runtime_minutes': 141,
#   'rating': 'R',
#   'budget': 32000000},
#  {'movie_title': 'Operation Finale',
#   'domestic_total_gross': 17612099,
#   'runtime_minutes': 122,
#   'rating': 'PG-13',
#   'budget': 24000000},
#  {'movie_title': 'Paul, Apostle of Christ',
#   'domestic_total_gross': 17560475,
#   'runtime_minutes': 108,
#   'rating': 'PG-13',
#   'budget': 5000000},
#  {'movie_title': 'Lady Bird',
#   'domestic_total_gross': 48958273,
#   'runtime_minutes': 94,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Sorry to Bother You',
#   'domestic_total_gross': 17493096,
#   'runtime_minutes': 112,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Chappaquiddick',
#   'domestic_total_gross': 17395520,
#   'runtime_minutes': 106,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Forever My Girl',
#   'domestic_total_gross': 16376066,
#   'runtime_minutes': 108,
#   'rating': 'PG',
#   'budget': 3500000},
#  {'movie_title': 'The Favourite',
#   'domestic_total_gross': 34366783,
#   'runtime_minutes': 119,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Hunter Killer',
#   'domestic_total_gross': 15767460,
#   'runtime_minutes': 121,
#   'rating': 'R',
#   'budget': 40000000},
#  {'movie_title': 'Mortal Engines',
#   'domestic_total_gross': 15951040,
#   'runtime_minutes': 128,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': "The Girl in the Spider's Web",
#   'domestic_total_gross': 14841338,
#   'runtime_minutes': 115,
#   'rating': 'R',
#   'budget': 43000000},
#  {'movie_title': 'The Possession of Hannah Grace',
#   'domestic_total_gross': 14837422,
#   'runtime_minutes': 86,
#   'rating': 'R',
#   'budget': 7700000},
#  {'movie_title': 'RBG',
#   'domestic_total_gross': 14017361,
#   'runtime_minutes': 98,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Eighth Grade',
#   'domestic_total_gross': 13539709,
#   'runtime_minutes': 93,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Call Me by Your Name',
#   'domestic_total_gross': 18095701,
#   'runtime_minutes': 132,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Darkest Minds',
#   'domestic_total_gross': 12695691,
#   'runtime_minutes': 104,
#   'rating': 'PG-13',
#   'budget': 34000000},
#  {'movie_title': 'All the Money in the World',
#   'domestic_total_gross': 25113707,
#   'runtime_minutes': 132,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Three Identical Strangers',
#   'domestic_total_gross': 12320845,
#   'runtime_minutes': 96,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Upgrade',
#   'domestic_total_gross': 11977130,
#   'runtime_minutes': 100,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Padmaavat',
#   'domestic_total_gross': 11846060,
#   'runtime_minutes': 164,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Free Solo',
#   'domestic_total_gross': 17541090,
#   'runtime_minutes': 100,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The Old Man & the Gun',
#   'domestic_total_gross': 11277120,
#   'runtime_minutes': 93,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Hell Fest',
#   'domestic_total_gross': 11107431,
#   'runtime_minutes': 89,
#   'rating': 'R',
#   'budget': 5500000},
#  {'movie_title': 'Wonder',
#   'domestic_total_gross': 132422809,
#   'runtime_minutes': 113,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'The Miracle Season',
#   'domestic_total_gross': 10230620,
#   'runtime_minutes': 101,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Mary Queen of Scots',
#   'domestic_total_gross': 16468499,
#   'runtime_minutes': 124,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Midnight Sun',
#   'domestic_total_gross': 9561064,
#   'runtime_minutes': 91,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Tully',
#   'domestic_total_gross': 9369755,
#   'runtime_minutes': 95,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Traffik',
#   'domestic_total_gross': 9186156,
#   'runtime_minutes': 96,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Unfriended: Dark Web',
#   'domestic_total_gross': 8866745,
#   'runtime_minutes': 92,
#   'rating': 'R',
#   'budget': 1000000},
#  {'movie_title': 'Welcome to Marwen',
#   'domestic_total_gross': 10763520,
#   'runtime_minutes': 116,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Early Man',
#   'domestic_total_gross': 8267544,
#   'runtime_minutes': 89,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'The Wife',
#   'domestic_total_gross': 9601092,
#   'runtime_minutes': 99,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Death of Stalin',
#   'domestic_total_gross': 8047856,
#   'runtime_minutes': 107,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'They Shall Not Grow Old 2018 Re',
#   'domestic_total_gross': 17956913,
#   'runtime_minutes': 99,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Sanju',
#   'domestic_total_gross': 7909317,
#   'runtime_minutes': 155,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Unsane',
#   'domestic_total_gross': 7732899,
#   'runtime_minutes': 98,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Beautiful Boy',
#   'domestic_total_gross': 7649973,
#   'runtime_minutes': None,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Can You Ever Forgive Me?',
#   'domestic_total_gross': 8803865,
#   'runtime_minutes': 106,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Mid90s',
#   'domestic_total_gross': 7362439,
#   'runtime_minutes': 85,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Downsizing',
#   'domestic_total_gross': 24449754,
#   'runtime_minutes': 135,
#   'rating': 'R',
#   'budget': 68000000},
#  {'movie_title': 'Dog Days',
#   'domestic_total_gross': 6809080,
#   'runtime_minutes': 113,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Boy Erased',
#   'domestic_total_gross': 6788692,
#   'runtime_minutes': 115,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Hotel Artemis',
#   'domestic_total_gross': 6708147,
#   'runtime_minutes': 94,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'A',
#   'domestic_total_gross': 6501381,
#   'runtime_minutes': 98,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Fahrenheit 11/9',
#   'domestic_total_gross': 6352306,
#   'runtime_minutes': 128,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Unbroken: Path to Redemption',
#   'domestic_total_gross': 6216897,
#   'runtime_minutes': 98,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The Hurricane Heist',
#   'domestic_total_gross': 6115825,
#   'runtime_minutes': 103,
#   'rating': 'PG-13',
#   'budget': 35000000},
#  {'movie_title': 'Every Day',
#   'domestic_total_gross': 6102076,
#   'runtime_minutes': 97,
#   'rating': 'PG-13',
#   'budget': 4900000},
#  {'movie_title': 'Leave No Trace',
#   'domestic_total_gross': 6046104,
#   'runtime_minutes': 109,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Once Upon a Deadpool 2018 Re',
#   'domestic_total_gross': 6100309,
#   'runtime_minutes': 119,
#   'rating': 'R',
#   'budget': 110000000},
#  {'movie_title': 'Death of a Nation',
#   'domestic_total_gross': 5885881,
#   'runtime_minutes': 108,
#   'rating': 'PG-13',
#   'budget': 6000000},
#  {'movie_title': 'Pandas',
#   'domestic_total_gross': 7574012,
#   'runtime_minutes': None,
#   'rating': 'G',
#   'budget': 0},
#  {'movie_title': 'My Hero Academia: Two Heroes',
#   'domestic_total_gross': 5754556,
#   'runtime_minutes': 96,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': "God's Not Dead: A Light in Darkness",
#   'domestic_total_gross': 5728940,
#   'runtime_minutes': 105,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Kin',
#   'domestic_total_gross': 5718096,
#   'runtime_minutes': 102,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Colette',
#   'domestic_total_gross': 5137622,
#   'runtime_minutes': 111,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Action Point',
#   'domestic_total_gross': 5059608,
#   'runtime_minutes': 85,
#   'rating': 'R',
#   'budget': 19000000},
#  {'movie_title': 'Beirut',
#   'domestic_total_gross': 5019226,
#   'runtime_minutes': 109,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Gringo',
#   'domestic_total_gross': 4969853,
#   'runtime_minutes': 111,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Samson',
#   'domestic_total_gross': 4719928,
#   'runtime_minutes': 110,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Father Figures',
#   'domestic_total_gross': 17501244,
#   'runtime_minutes': 113,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Johnny English Strikes Again',
#   'domestic_total_gross': 4412170,
#   'runtime_minutes': 89,
#   'rating': 'PG',
#   'budget': 25000000},
#  {'movie_title': 'Gotti',
#   'domestic_total_gross': 4343227,
#   'runtime_minutes': 112,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Blindspotting',
#   'domestic_total_gross': 4333394,
#   'runtime_minutes': 95,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Burn the Stage: The Movie',
#   'domestic_total_gross': 4201819,
#   'runtime_minutes': 84,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Ya veremos',
#   'domestic_total_gross': 4165949,
#   'runtime_minutes': 85,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Life Itself',
#   'domestic_total_gross': 4102648,
#   'runtime_minutes': 117,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Sgt. Stubby: An American Hero',
#   'domestic_total_gross': 4015935,
#   'runtime_minutes': 84,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Thor: Ragnarok',
#   'domestic_total_gross': 315058289,
#   'runtime_minutes': 130,
#   'rating': 'PG-13',
#   'budget': 180000000},
#  {'movie_title': "Gosnell: The Trial of America's Biggest Serial Killer",
#   'domestic_total_gross': 3679893,
#   'runtime_minutes': 93,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Indivisible',
#   'domestic_total_gross': 3511417,
#   'runtime_minutes': 119,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The Oscar Nominated Short Films 2018: Live Action',
#   'domestic_total_gross': 3508777,
#   'runtime_minutes': 96,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Disobedience',
#   'domestic_total_gross': 3498782,
#   'runtime_minutes': 114,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Justice League',
#   'domestic_total_gross': 229024295,
#   'runtime_minutes': None,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'First Reformed',
#   'domestic_total_gross': 3448256,
#   'runtime_minutes': 113,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Juliet, Naked',
#   'domestic_total_gross': 3444895,
#   'runtime_minutes': 97,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Bad Samaritan',
#   'domestic_total_gross': 3435047,
#   'runtime_minutes': 110,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': '7 Days in Entebbe',
#   'domestic_total_gross': 3326885,
#   'runtime_minutes': 107,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The Disaster Artist',
#   'domestic_total_gross': 21120616,
#   'runtime_minutes': 104,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': '2001: A Space Odyssey 2017 Re',
#   'domestic_total_gross': 3236321,
#   'runtime_minutes': 149,
#   'rating': None,
#   'budget': 12000000},
#  {'movie_title': '2.0',
#   'domestic_total_gross': 4152000,
#   'runtime_minutes': 148,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Leisure Seeker',
#   'domestic_total_gross': 3226443,
#   'runtime_minutes': 112,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Sisters Brothers',
#   'domestic_total_gross': 3143056,
#   'runtime_minutes': 122,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Thoroughbreds',
#   'domestic_total_gross': 3072605,
#   'runtime_minutes': 92,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Whitney',
#   'domestic_total_gross': 3026351,
#   'runtime_minutes': None,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'American Animals',
#   'domestic_total_gross': 2856954,
#   'runtime_minutes': 116,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'God Bless the Broken Road',
#   'domestic_total_gross': 2846257,
#   'runtime_minutes': 111,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'La boda de Valentina',
#   'domestic_total_gross': 2783739,
#   'runtime_minutes': 107,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Bharath Ane Nenu',
#   'domestic_total_gross': 2663090,
#   'runtime_minutes': 173,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'You Were Never Really Here',
#   'domestic_total_gross': 2528078,
#   'runtime_minutes': 89,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'A Beautiful Planet',
#   'domestic_total_gross': 15650615,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Suspiria',
#   'domestic_total_gross': 2483472,
#   'runtime_minutes': 152,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Rider',
#   'domestic_total_gross': 2419031,
#   'runtime_minutes': 104,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': "Mary and the Witch's Flower",
#   'domestic_total_gross': 2418404,
#   'runtime_minutes': 103,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Hearts Beat Loud',
#   'domestic_total_gross': 2386251,
#   'runtime_minutes': 97,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': '1991',
#   'domestic_total_gross': 2342264,
#   'runtime_minutes': 141,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Papillon',
#   'domestic_total_gross': 2335896,
#   'runtime_minutes': 133,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': "Daddy's Home 2",
#   'domestic_total_gross': 104029443,
#   'runtime_minutes': 100,
#   'rating': 'PG-13',
#   'budget': 69000000},
#  {'movie_title': 'Murder on the Orient Express',
#   'domestic_total_gross': 102826543,
#   'runtime_minutes': 114,
#   'rating': 'PG-13',
#   'budget': 55000000},
#  {'movie_title': 'If Beale Street Could Talk',
#   'domestic_total_gross': 14915773,
#   'runtime_minutes': 119,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Simmba',
#   'domestic_total_gross': 5102129,
#   'runtime_minutes': 158,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Fall of the American Empire',
#   'domestic_total_gross': 2178460,
#   'runtime_minutes': 127,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Puzzle',
#   'domestic_total_gross': 2032018,
#   'runtime_minutes': 103,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Great Performances at the Met: Puccini: Tosca',
#   'domestic_total_gross': 2023749,
#   'runtime_minutes': 150,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'A Fantastic Woman',
#   'domestic_total_gross': 2020988,
#   'runtime_minutes': 104,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Pope Francis: A Man of His Word',
#   'domestic_total_gross': 2008385,
#   'runtime_minutes': 96,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Assassination Nation',
#   'domestic_total_gross': 2005142,
#   'runtime_minutes': 108,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Front Runner',
#   'domestic_total_gross': 2000105,
#   'runtime_minutes': 113,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Detective Chinatown 2',
#   'domestic_total_gross': 1983984,
#   'runtime_minutes': 121,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Great Performances at the Met: Verdi: La Traviata',
#   'domestic_total_gross': 1882931,
#   'runtime_minutes': 205,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Ben Is Back',
#   'domestic_total_gross': 3703184,
#   'runtime_minutes': 103,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': "At Eternity's Gate",
#   'domestic_total_gross': 2294915,
#   'runtime_minutes': 111,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Moses',
#   'domestic_total_gross': 1807117,
#   'runtime_minutes': 130,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Great Performances at the Met: Puccini: La Bohème',
#   'domestic_total_gross': 1764201,
#   'runtime_minutes': 187,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Race 3',
#   'domestic_total_gross': 1690861,
#   'runtime_minutes': 160,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'On the Basis of Sex',
#   'domestic_total_gross': 24622687,
#   'runtime_minutes': None,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Pad Man',
#   'domestic_total_gross': 1670192,
#   'runtime_minutes': 140,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'A Private War',
#   'domestic_total_gross': 1633208,
#   'runtime_minutes': 110,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Great Performances at the Met: Verdi: Aida',
#   'domestic_total_gross': 1595902,
#   'runtime_minutes': 225,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Bookshop',
#   'domestic_total_gross': 1588150,
#   'runtime_minutes': 113,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Operation Red Sea',
#   'domestic_total_gross': 1543547,
#   'runtime_minutes': 142,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Thugs of Hindostan',
#   'domestic_total_gross': 1449848,
#   'runtime_minutes': 164,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': "Don't Worry, He Won't Get Far on Foot",
#   'domestic_total_gross': 1441705,
#   'runtime_minutes': 114,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Princess Mononoke 2018 Re',
#   'domestic_total_gross': 1423877,
#   'runtime_minutes': 134,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Finding Your Feet',
#   'domestic_total_gross': 1418682,
#   'runtime_minutes': 111,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Made for More',
#   'domestic_total_gross': 2999134,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Little Women',
#   'domestic_total_gross': 1379497,
#   'runtime_minutes': 112,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Dunkirk 2017 Re',
#   'domestic_total_gross': 1695119,
#   'runtime_minutes': 106,
#   'rating': 'PG-13',
#   'budget': 100000000},
#  {'movie_title': '102 Not Out',
#   'domestic_total_gross': 1343797,
#   'runtime_minutes': 102,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Baaghi 2',
#   'domestic_total_gross': 1319579,
#   'runtime_minutes': 137,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Great Performances at the Met: Mozart: Così fan tutte',
#   'domestic_total_gross': 1302949,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'McQueen',
#   'domestic_total_gross': 1257275,
#   'runtime_minutes': 111,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Seagull',
#   'domestic_total_gross': 1252960,
#   'runtime_minutes': 98,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Great Performances at the Met: Massenet: Cendrillon',
#   'domestic_total_gross': 1243306,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Racetime',
#   'domestic_total_gross': 1875283,
#   'runtime_minutes': 89,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Shoplifters',
#   'domestic_total_gross': 3313513,
#   'runtime_minutes': 121,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Mandy',
#   'domestic_total_gross': 1214525,
#   'runtime_minutes': 121,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Maria By Callas 2018 Re',
#   'domestic_total_gross': 1267301,
#   'runtime_minutes': 119,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Grease 2018 Re',
#   'domestic_total_gross': 1213413,
#   'runtime_minutes': 110,
#   'rating': 'PG',
#   'budget': 6000000},
#  {'movie_title': 'Beautifully Broken',
#   'domestic_total_gross': 1209645,
#   'runtime_minutes': 108,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'An Interview with God',
#   'domestic_total_gross': 1201434,
#   'runtime_minutes': 97,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Along With the Gods: The Last 49 Days',
#   'domestic_total_gross': 1200246,
#   'runtime_minutes': 142,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Great Performances at the Met: Saint',
#   'domestic_total_gross': 1195758,
#   'runtime_minutes': 200,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Andhadhun',
#   'domestic_total_gross': 1193046,
#   'runtime_minutes': 139,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Spirited Away 2018 Re',
#   'domestic_total_gross': 1175067,
#   'runtime_minutes': 125,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Great Performances at the Met: Verdi: Luisa Miller',
#   'domestic_total_gross': 1166858,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Lean on Pete',
#   'domestic_total_gross': 1163056,
#   'runtime_minutes': 121,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Along With the Gods: The Two Worlds',
#   'domestic_total_gross': 1908823,
#   'runtime_minutes': 139,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'My Neighbor Totoro 2018 Re',
#   'domestic_total_gross': 1144649,
#   'runtime_minutes': 86,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': "Great Performances at the Met: Donizetti: L'Elisir d'Amore",
#   'domestic_total_gross': 1115018,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Qué León',
#   'domestic_total_gross': 2607916,
#   'runtime_minutes': 93,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The Dark Crystal 2018 Re',
#   'domestic_total_gross': 1036956,
#   'runtime_minutes': 93,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Zero',
#   'domestic_total_gross': 1035388,
#   'runtime_minutes': 164,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Great Performances at the Met: Rossini: Semiramide',
#   'domestic_total_gross': 1033651,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Great Performances at the Met: Puccini: La Fanciulla del West',
#   'domestic_total_gross': 1023233,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Nothing to Lose',
#   'domestic_total_gross': 1016188,
#   'runtime_minutes': 134,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Elvis: The Comeback Special',
#   'domestic_total_gross': 1010657,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Raid',
#   'domestic_total_gross': 1010385,
#   'runtime_minutes': 122,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Wildlife',
#   'domestic_total_gross': 1050616,
#   'runtime_minutes': 105,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The Insult',
#   'domestic_total_gross': 1001305,
#   'runtime_minutes': 113,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Labyrinth 2018 Re',
#   'domestic_total_gross': 993336,
#   'runtime_minutes': 101,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Yellow Submarine',
#   'domestic_total_gross': 992305,
#   'runtime_minutes': 90,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Little Italy',
#   'domestic_total_gross': 990230,
#   'runtime_minutes': 102,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Tiger Zinda Hai',
#   'domestic_total_gross': 5560921,
#   'runtime_minutes': 161,
#   'rating': None,
#   'budget': 20470000},
#  {'movie_title': "Film Stars Don't Die in Liverpool",
#   'domestic_total_gross': 1026124,
#   'runtime_minutes': 105,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Dawn Wall 2018 Re',
#   'domestic_total_gross': 970032,
#   'runtime_minutes': 100,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'White Christmas 2018 Re',
#   'domestic_total_gross': 928298,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Kirk Cameron: Connect',
#   'domestic_total_gross': 918127,
#   'runtime_minutes': 70,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Miseducation of Cameron Post',
#   'domestic_total_gross': 904703,
#   'runtime_minutes': 91,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Kedarnath',
#   'domestic_total_gross': 901131,
#   'runtime_minutes': 116,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Let the Sunshine In',
#   'domestic_total_gross': 892421,
#   'runtime_minutes': 94,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Star',
#   'domestic_total_gross': 40852824,
#   'runtime_minutes': 86,
#   'rating': 'PG',
#   'budget': 20000000},
#  {'movie_title': 'The Cakemaker',
#   'domestic_total_gross': 875751,
#   'runtime_minutes': 113,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Tea With the Dames',
#   'domestic_total_gross': 889343,
#   'runtime_minutes': 84,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Great Performances at the Met: Nico Muhly: Marnie',
#   'domestic_total_gross': 849710,
#   'runtime_minutes': 150,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'BANDSTAND: The Broadway Musical on Screen',
#   'domestic_total_gross': 839554,
#   'runtime_minutes': 130,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': "Schindler's List 2018 Re",
#   'domestic_total_gross': 833050,
#   'runtime_minutes': 195,
#   'rating': 'R',
#   'budget': 22000000},
#  {'movie_title': 'Like Arrows',
#   'domestic_total_gross': 817990,
#   'runtime_minutes': 100,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Beast',
#   'domestic_total_gross': 800365,
#   'runtime_minutes': 107,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Made in India',
#   'domestic_total_gross': 790628,
#   'runtime_minutes': 122,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Pokémon the Movie: The Power of Us',
#   'domestic_total_gross': 789170,
#   'runtime_minutes': 100,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Border',
#   'domestic_total_gross': 771930,
#   'runtime_minutes': 110,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': '1945',
#   'domestic_total_gross': 1006193,
#   'runtime_minutes': 91,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Party',
#   'domestic_total_gross': 749827,
#   'runtime_minutes': 71,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'How Long Will I Love U',
#   'domestic_total_gross': 746933,
#   'runtime_minutes': 101,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'On Chesil Beach',
#   'domestic_total_gross': 745971,
#   'runtime_minutes': 110,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Polar Express 2018 Re',
#   'domestic_total_gross': 731018,
#   'runtime_minutes': 100,
#   'rating': None,
#   'budget': 165000000},
#  {'movie_title': 'The Catcher Was a Spy',
#   'domestic_total_gross': 725223,
#   'runtime_minutes': 98,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Little Stranger',
#   'domestic_total_gross': 713143,
#   'runtime_minutes': 111,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Mirai',
#   'domestic_total_gross': 812794,
#   'runtime_minutes': 98,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'HBO Boxing: Canelo Alvarez vs. Gennady Golovkin II',
#   'domestic_total_gross': 707875,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Monster Hunt 2',
#   'domestic_total_gross': 706153,
#   'runtime_minutes': 110,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Blaze',
#   'domestic_total_gross': 704955,
#   'runtime_minutes': 129,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Boundaries',
#   'domestic_total_gross': 703438,
#   'runtime_minutes': 104,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': "Jim Henson's Holiday Special with Fraggle Rock and Emmet Otter",
#   'domestic_total_gross': 695130,
#   'runtime_minutes': 103,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Vox Lux',
#   'domestic_total_gross': 727119,
#   'runtime_minutes': 114,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Trump Prophecy',
#   'domestic_total_gross': 671198,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Island',
#   'domestic_total_gross': 670883,
#   'runtime_minutes': 134,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Bombshell: The Hedy Lamarr Story',
#   'domestic_total_gross': 820300,
#   'runtime_minutes': 88,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Dragon Ball Z: Broly',
#   'domestic_total_gross': 658982,
#   'runtime_minutes': 72,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Ponyo 2018 Re',
#   'domestic_total_gross': 653072,
#   'runtime_minutes': 101,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Lizzie',
#   'domestic_total_gross': 642157,
#   'runtime_minutes': 105,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Love, Gilda',
#   'domestic_total_gross': 626318,
#   'runtime_minutes': 88,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Transformers',
#   'domestic_total_gross': 619597,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Foxtrot',
#   'domestic_total_gross': 618883,
#   'runtime_minutes': 113,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Sound of Music 2018 Re',
#   'domestic_total_gross': 616171,
#   'runtime_minutes': 172,
#   'rating': None,
#   'budget': 8200000},
#  {'movie_title': 'Itzhak',
#   'domestic_total_gross': 607290,
#   'runtime_minutes': 82,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Florida Project',
#   'domestic_total_gross': 5904366,
#   'runtime_minutes': 111,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': "The Walking Dead: Wrath/The Walking Dead/Fear the Walking Dead: What's Your Story?/Fear the Walking Dead 2018 NCM Fathom Event",
#   'domestic_total_gross': 605764,
#   'runtime_minutes': 185,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'DCI 2019: Big, Loud & Live 16',
#   'domestic_total_gross': 603320,
#   'runtime_minutes': 325,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Grateful Dead Meet',
#   'domestic_total_gross': 600554,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Burning',
#   'domestic_total_gross': 718991,
#   'runtime_minutes': 148,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Marshall',
#   'domestic_total_gross': 10051659,
#   'runtime_minutes': 118,
#   'rating': 'PG-13',
#   'budget': 12000000},
#  {'movie_title': 'The Big Lebowski 2018 Re',
#   'domestic_total_gross': 582585,
#   'runtime_minutes': 117,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Pick of the Litter',
#   'domestic_total_gross': 578717,
#   'runtime_minutes': 80,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Husband Material',
#   'domestic_total_gross': 567417,
#   'runtime_minutes': 156,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Riot and the Dance',
#   'domestic_total_gross': 316103,
#   'runtime_minutes': 83,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Loveless',
#   'domestic_total_gross': 566356,
#   'runtime_minutes': 127,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Cat Returns 2018 Re',
#   'domestic_total_gross': 563718,
#   'runtime_minutes': 75,
#   'rating': 'G',
#   'budget': 0},
#  {'movie_title': 'The Ex',
#   'domestic_total_gross': 838959,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Room 2017 Re',
#   'domestic_total_gross': 549602,
#   'runtime_minutes': 99,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'A Cool Fish',
#   'domestic_total_gross': 551876,
#   'runtime_minutes': 109,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Children Act',
#   'domestic_total_gross': 547750,
#   'runtime_minutes': 105,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Dragon Ball Z: Bardock',
#   'domestic_total_gross': 540707,
#   'runtime_minutes': 99,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Anna and the Apocalypse',
#   'domestic_total_gross': 545597,
#   'runtime_minutes': 93,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Fireworks',
#   'domestic_total_gross': 525280,
#   'runtime_minutes': 90,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Castle in the Sky 2018 Re',
#   'domestic_total_gross': 523664,
#   'runtime_minutes': 125,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Grave of the Fireflies',
#   'domestic_total_gross': 516962,
#   'runtime_minutes': 89,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Sandlot 2018 Re',
#   'domestic_total_gross': 516130,
#   'runtime_minutes': 101,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Bullitt 2018 Re',
#   'domestic_total_gross': 511350,
#   'runtime_minutes': 114,
#   'rating': 'M/PG',
#   'budget': 0},
#  {'movie_title': 'Die Hard 30th Anniversary Release',
#   'domestic_total_gross': 510241,
#   'runtime_minutes': 132,
#   'rating': None,
#   'budget': 28000000},
#  {'movie_title': 'The Spy Gone North',
#   'domestic_total_gross': 500803,
#   'runtime_minutes': 137,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Monsters and Men',
#   'domestic_total_gross': 500101,
#   'runtime_minutes': 96,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Bilal: A New Breed of Hero 2018 Re',
#   'domestic_total_gross': 490973,
#   'runtime_minutes': 105,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The Great Battle',
#   'domestic_total_gross': 472166,
#   'runtime_minutes': 136,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Happy Prince',
# ...
#   'runtime_minutes': 85,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Oolong Courtyard: KungFu School',
#   'domestic_total_gross': 37727,
#   'runtime_minutes': 103,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Krystal',
#   'domestic_total_gross': 37516,
#   'runtime_minutes': 90,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Hale County This Morning, This Evening',
#   'domestic_total_gross': 112282,
#   'runtime_minutes': 76,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Other Side of Hope',
#   'domestic_total_gross': 183943,
#   'runtime_minutes': 100,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Girls vs Gangsters',
#   'domestic_total_gross': 37115,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Breath',
#   'domestic_total_gross': 37108,
#   'runtime_minutes': 115,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Small Group',
#   'domestic_total_gross': 37058,
#   'runtime_minutes': None,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Searching for Ingmar Bergman',
#   'domestic_total_gross': 36686,
#   'runtime_minutes': 99,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Mind Game',
#   'domestic_total_gross': 36613,
#   'runtime_minutes': 103,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Divide and Conquer',
#   'domestic_total_gross': 38510,
#   'runtime_minutes': 107,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Le Corbeau',
#   'domestic_total_gross': 36089,
#   'runtime_minutes': 92,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The House of Tomorrow',
#   'domestic_total_gross': 35821,
#   'runtime_minutes': 85,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Big Bad Fox and Other Tales 2017 Re',
#   'domestic_total_gross': 35787,
#   'runtime_minutes': 83,
#   'rating': 'G',
#   'budget': 0},
#  {'movie_title': 'The Road Movie',
#   'domestic_total_gross': 35757,
#   'runtime_minutes': 67,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': "For Those Who Don't Read Me",
#   'domestic_total_gross': 36506,
#   'runtime_minutes': 107,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Just Getting Started',
#   'domestic_total_gross': 6069605,
#   'runtime_minutes': 91,
#   'rating': 'PG-13',
#   'budget': 22000000},
#  {'movie_title': '24 Frames',
#   'domestic_total_gross': 34482,
#   'runtime_minutes': 114,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Space Station 3D',
#   'domestic_total_gross': 93383953,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Holy Hell',
#   'domestic_total_gross': 34366,
#   'runtime_minutes': 89,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Maui',
#   'domestic_total_gross': 33953,
#   'runtime_minutes': 95,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'No Date, No Signature',
#   'domestic_total_gross': 36444,
#   'runtime_minutes': 99,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Sollers Point',
#   'domestic_total_gross': 32608,
#   'runtime_minutes': 101,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'BPM (Beats Per Minute)',
#   'domestic_total_gross': 125189,
#   'runtime_minutes': 143,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Liyana',
#   'domestic_total_gross': 44045,
#   'runtime_minutes': 77,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Goodland',
#   'domestic_total_gross': 32140,
#   'runtime_minutes': 84,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Moynihan',
#   'domestic_total_gross': 31970,
#   'runtime_minutes': 102,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Saving Brinton',
#   'domestic_total_gross': 56218,
#   'runtime_minutes': 90,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Good Manners',
#   'domestic_total_gross': 31177,
#   'runtime_minutes': 135,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Poor Boy',
#   'domestic_total_gross': 31031,
#   'runtime_minutes': 104,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Galapagos',
#   'domestic_total_gross': 18630372,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Cold Water',
#   'domestic_total_gross': 30209,
#   'runtime_minutes': 95,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Desert Bride',
#   'domestic_total_gross': 30110,
#   'runtime_minutes': 78,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Desolation',
#   'domestic_total_gross': 18490,
#   'runtime_minutes': 90,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Memories of Underdevelopment 2018 Re',
#   'domestic_total_gross': 29647,
#   'runtime_minutes': 97,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Same Kind of Different as Me',
#   'domestic_total_gross': 6423605,
#   'runtime_minutes': 119,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'The Mercy 2018 Re',
#   'domestic_total_gross': 29538,
#   'runtime_minutes': 112,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Charm City',
#   'domestic_total_gross': 29335,
#   'runtime_minutes': 108,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Restoring Tomorrow',
#   'domestic_total_gross': 28556,
#   'runtime_minutes': 82,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'The Apparition',
#   'domestic_total_gross': 28293,
#   'runtime_minutes': 144,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'On Her Shoulders',
#   'domestic_total_gross': 28288,
#   'runtime_minutes': 95,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Quai des Orfèvres 2018 Re',
#   'domestic_total_gross': 28013,
#   'runtime_minutes': 106,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Amendment',
#   'domestic_total_gross': 27961,
#   'runtime_minutes': 90,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Horn from the Heart: The Paul Butterfield Story',
#   'domestic_total_gross': 58597,
#   'runtime_minutes': 95,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Senso',
#   'domestic_total_gross': 27723,
#   'runtime_minutes': 123,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Cured',
#   'domestic_total_gross': 26630,
#   'runtime_minutes': 95,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Milford Graves Full Mantis',
#   'domestic_total_gross': 26566,
#   'runtime_minutes': 91,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Belle de Jour 2017 Re',
#   'domestic_total_gross': 26331,
#   'runtime_minutes': 100,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Misandrists',
#   'domestic_total_gross': 26123,
#   'runtime_minutes': 91,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Ridge Runners',
#   'domestic_total_gross': 26019,
#   'runtime_minutes': 81,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Jet Trash 2018 Re',
#   'domestic_total_gross': 26002,
#   'runtime_minutes': 85,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Birdboy: The Forgotten Children',
#   'domestic_total_gross': 38786,
#   'runtime_minutes': 76,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Let There Be Light',
#   'domestic_total_gross': 7233471,
#   'runtime_minutes': 100,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'No Intenso Agora',
#   'domestic_total_gross': 24955,
#   'runtime_minutes': 127,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': "An Elephant's Journey",
#   'domestic_total_gross': 24844,
#   'runtime_minutes': 87,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Day After',
#   'domestic_total_gross': 24746,
#   'runtime_minutes': 92,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Night of 7 Years',
#   'domestic_total_gross': 24281,
#   'runtime_minutes': 123,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Elliot the Littlest Reindeer 2018 Re',
#   'domestic_total_gross': 24262,
#   'runtime_minutes': 89,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Death House',
#   'domestic_total_gross': 23833,
#   'runtime_minutes': 95,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Swimming with Men',
#   'domestic_total_gross': 24708,
#   'runtime_minutes': 96,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Vazante',
#   'domestic_total_gross': 23884,
#   'runtime_minutes': 116,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Divine Order',
#   'domestic_total_gross': 76277,
#   'runtime_minutes': 96,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Letter from Masanjia',
#   'domestic_total_gross': 23481,
#   'runtime_minutes': 75,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Take Point',
#   'domestic_total_gross': 112386,
#   'runtime_minutes': 119,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Atomic Cafe',
#   'domestic_total_gross': 22293,
#   'runtime_minutes': 86,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Judge',
#   'domestic_total_gross': 22257,
#   'runtime_minutes': 76,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Winning Formula',
#   'domestic_total_gross': 22189,
#   'runtime_minutes': 93,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Workshop',
#   'domestic_total_gross': 22061,
#   'runtime_minutes': 113,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Loving Pablo',
#   'domestic_total_gross': 22017,
#   'runtime_minutes': 123,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Female Brain',
#   'domestic_total_gross': 21786,
#   'runtime_minutes': 98,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'A Paris Education',
#   'domestic_total_gross': 21598,
#   'runtime_minutes': 137,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Half the Picture',
#   'domestic_total_gross': 21589,
#   'runtime_minutes': 94,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Primal Rage: The Legend of Konga',
#   'domestic_total_gross': 21497,
#   'runtime_minutes': 106,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Journey to the South Pacific',
#   'domestic_total_gross': 7653913,
#   'runtime_minutes': None,
#   'rating': 'G',
#   'budget': 0},
#  {'movie_title': 'Ganja & Hess',
#   'domestic_total_gross': 21197,
#   'runtime_minutes': 110,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Happys',
#   'domestic_total_gross': 21108,
#   'runtime_minutes': 87,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Ava',
#   'domestic_total_gross': 20940,
#   'runtime_minutes': 102,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Did You Wonder Who Fired the Gun?',
#   'domestic_total_gross': 20765,
#   'runtime_minutes': 90,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Tag Along: Devil Fish',
#   'domestic_total_gross': 20726,
#   'runtime_minutes': 114,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Ice Dragon: Legend of the Blue Daisies',
#   'domestic_total_gross': 20549,
#   'runtime_minutes': 70,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Devil and Father Amorth',
#   'domestic_total_gross': 20449,
#   'runtime_minutes': 68,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Izzy Gets the F*ck Across Town',
#   'domestic_total_gross': 20208,
#   'runtime_minutes': 86,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Last Resort',
#   'domestic_total_gross': 158646,
#   'runtime_minutes': 70,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Apocalypsis',
#   'domestic_total_gross': 20052,
#   'runtime_minutes': 90,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': "Eight Hours Don't Make a Day",
#   'domestic_total_gross': 19987,
#   'runtime_minutes': 476,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': "One Sings, the Other Doesn't",
#   'domestic_total_gross': 19919,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Active Measures',
#   'domestic_total_gross': 19862,
#   'runtime_minutes': 109,
#   'rating': 'PG-13',
#   'budget': 0},
#  {'movie_title': 'Freak Show',
#   'domestic_total_gross': 19696,
#   'runtime_minutes': 91,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': "God's Own Country",
#   'domestic_total_gross': 335609,
#   'runtime_minutes': 104,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'To the Arctic 3D',
#   'domestic_total_gross': 14560838,
#   'runtime_minutes': None,
#   'rating': 'G',
#   'budget': 0},
#  {'movie_title': 'Who We Are Now',
#   'domestic_total_gross': 19128,
#   'runtime_minutes': 95,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'November',
#   'domestic_total_gross': 19084,
#   'runtime_minutes': 115,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Anything',
#   'domestic_total_gross': 19037,
#   'runtime_minutes': 94,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Crime + Punishment',
#   'domestic_total_gross': 18644,
#   'runtime_minutes': 112,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Mrs. Hyde',
#   'domestic_total_gross': 18627,
#   'runtime_minutes': 95,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Maquia: When the Promised Flower Blooms 2018 Re',
#   'domestic_total_gross': 18539,
#   'runtime_minutes': 115,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Allegiance to Broadway',
#   'domestic_total_gross': 18527,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Gabriel and the Mountain',
#   'domestic_total_gross': 18415,
#   'runtime_minutes': 131,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': '306 Hollywood',
#   'domestic_total_gross': 18399,
#   'runtime_minutes': 94,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Marlina the Murderer in Four Acts',
#   'domestic_total_gross': 17788,
#   'runtime_minutes': 93,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Batman: Mask of the Phantasm 2018 Re',
#   'domestic_total_gross': 17813,
#   'runtime_minutes': 76,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'King of Hearts',
#   'domestic_total_gross': 17646,
#   'runtime_minutes': 102,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Chronicle of Anna Magdalena Bach',
#   'domestic_total_gross': 17527,
#   'runtime_minutes': 94,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'A Bread Factory, Part One/A Bread Factory, Part Two',
#   'domestic_total_gross': 17325,
#   'runtime_minutes': 242,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Revival',
#   'domestic_total_gross': 17252,
#   'runtime_minutes': 105,
#   'rating': 'PG',
#   'budget': 0},
#  {'movie_title': 'Heading Home: The Tale of Team Israel',
#   'domestic_total_gross': 207533,
#   'runtime_minutes': 87,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Life and Nothing More',
#   'domestic_total_gross': 24358,
#   'runtime_minutes': 114,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Haikara',
#   'domestic_total_gross': 16572,
#   'runtime_minutes': 97,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Just One Drop',
#   'domestic_total_gross': 60078,
#   'runtime_minutes': 66,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Intent to Destroy: Death, Denial & Depiction 2017 Re',
#   'domestic_total_gross': 18340,
#   'runtime_minutes': 115,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Out on Stage',
#   'domestic_total_gross': 15623,
#   'runtime_minutes': None,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Bob le Flambeur',
#   'domestic_total_gross': 15586,
#   'runtime_minutes': 98,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'When You Read This Letter',
#   'domestic_total_gross': 15552,
#   'runtime_minutes': 104,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': "People's Republic of Desire",
#   'domestic_total_gross': 15241,
#   'runtime_minutes': 95,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Trust Machine: The Story of Blockchain',
#   'domestic_total_gross': 14905,
#   'runtime_minutes': 84,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Lucky Man',
#   'domestic_total_gross': 25015,
#   'runtime_minutes': 98,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'The Charmer',
#   'domestic_total_gross': 26167,
#   'runtime_minutes': 100,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'Thelma',
#   'domestic_total_gross': 147391,
#   'runtime_minutes': 116,
#   'rating': None,
#   'budget': 0},
#  {'movie_title': 'A Prayer Before Dawn',
#   'domestic_total_gross': 14453,
#   'runtime_minutes': 116,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'The Last Movie Star',
#   'domestic_total_gross': 14410,
#   'runtime_minutes': 94,
#   'rating': 'R',
#   'budget': 0},
#  {'movie_title': 'Narcissister Organ Player',
#   'domestic_total_gross': 15334,
#   'runtime_minutes': 91,
#   'rating': None,
#   'budget': 0}]

# %% [markdown]
# ###### Finally, we are saving this dictionary into a Pandas DataFrame and eventually a csv file for faster data analysis available to you in the next notebook.

# %%
movie_df_2018 = pd.DataFrame(dicts)

# %%
movie_df_2018.head()
# Out:
#                       movie_title  domestic_total_gross  runtime_minutes  \
# 0                   Black Panther             700059566            134.0
# 1          Avengers: Infinity War             678815482            149.0
# 2                   Incredibles 2             608581744            118.0
# 3  Jurassic World: Fallen Kingdom             417719760            128.0
# 4                      Deadpool 2             318491426            119.0
#
#   rating     budget
# 0  PG-13          0
# 1  PG-13          0
# 2     PG          0
# 3  PG-13  170000000
# 4      R  110000000

# %%
movie_df_2018.to_csv('box_office_mojo_data_2018.csv')

# %% [markdown]
# The code above saved our *movie_df_2018* dataframe into a csv in the working directory on my computer.

# %%
# Find the way to scrape for multiple years.

# %%
movie_df_2019 = pd.read_csv("box_office_mojo_data.csv")

# %%
movie_dfs = pd.concat([movie_df_2019, movie_df_2018])
# Out:
# /Users/sasha_prokhorova/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
movie_dfs.head()
# Out:
#    Unnamed: 0     budget  domestic_total_gross        movie_title rating  \
# 0         0.0  356000000             858373000  Avengers: Endgame  PG-13
# 1         1.0  260000000             543638043      The Lion King     PG
# 2         2.0  200000000             434038008        Toy Story 4      G
# 3         3.0  150000000             477373578          Frozen II     PG
# 4         4.0  160000000             426829839     Captain Marvel  PG-13
#
#    runtime_minutes
# 0            181.0
# 1            118.0
# 2            100.0
# 3            103.0
# 4            123.0

# %%
movie_dfs.shape
# Out:
# (1598, 6)
